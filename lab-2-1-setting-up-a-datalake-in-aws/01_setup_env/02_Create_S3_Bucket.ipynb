# %% [markdown]
# # Create S3 Bucket

# %%
pip install --upgrade boto3 botocore awscli
# Out:
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.12/site-packages (1.16.56)
# Collecting boto3
#   Using cached boto3-1.42.29-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: botocore in /opt/conda/lib/python3.12/site-packages (1.19.56)
# Collecting botocore
#   Using cached botocore-1.42.29-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: awscli in /opt/conda/lib/python3.12/site-packages (1.18.216)
# Collecting awscli
#   Using cached awscli-1.44.19-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3) (0.10.0)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3)
#   Using cached s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from botocore) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.12/site-packages (from botocore) (1.26.20)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore) (1.17.0)
# Collecting docutils<=0.19,>=0.18.1 (from awscli)
#   Using cached docutils-0.19-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: PyYAML<6.1,>=3.10 in /opt/conda/lib/python3.12/site-packages (from awscli) (5.3.1)
# Requirement already satisfied: colorama<0.4.7,>=0.2.5 in /opt/conda/lib/python3.12/site-packages (from awscli) (0.4.3)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from awscli) (4.5)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/lib/python3.12/site-packages (from rsa<4.8,>=3.1.2->awscli) (0.6.1)
# Using cached boto3-1.42.29-py3-none-any.whl (140 kB)
# Using cached botocore-1.42.29-py3-none-any.whl (14.6 MB)
# Using cached s3transfer-0.16.0-py3-none-any.whl (86 kB)
# Using cached awscli-1.44.19-py3-none-any.whl (4.6 MB)
# Using cached docutils-0.19-py3-none-any.whl (570 kB)
# Installing collected packages: docutils, botocore, s3transfer, boto3, awscli
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.15.2
#     Uninstalling docutils-0.15.2:
#       Successfully uninstalled docutils-0.15.2
#   Attempting uninstall: botocore━━━━━━━━━━━━━━━━ 0/5 [docutils]
#     Found existing installation: botocore 1.19.560/5 [docutils]
#     Uninstalling botocore-1.19.56:━━━━━━━━━━ 0/5 [docutils]
#       Successfully uninstalled botocore-1.19.56m 0/5 [docutils]
#   Attempting uninstall: s3transferm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/5 [botocore]
#     Found existing installation: s3transfer 0.3.7━━━━━━━━━━━━━ 1/5 [botocore]
#     Uninstalling s3transfer-0.3.7:━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/5 [botocore]
#       Successfully uninstalled s3transfer-0.3.7━━━━━━━━━━━━━━━ 1/5 [botocore]
#   Attempting uninstall: boto3╺━━━━━━━━━━━━━━━━━━━━━━━ 2/5 [s3transfer]
#     Found existing installation: boto3 1.16.56━━━━━━━━━━━━━━━━ 2/5 [s3transfer]
#     Uninstalling boto3-1.16.56:━━━━━━━━━━━━━━━━━━━━━━━ 2/5 [s3transfer]
#       Successfully uninstalled boto3-1.16.56━━━━━━━━━━━━━━━━━━ 2/5 [s3transfer]
#   Attempting uninstall: awscli━━━━━━━━━━━━━━━━━━━━━━━ 2/5 [s3transfer]
#     Found existing installation: awscli 1.18.216━━━━━━━━━━━━━━ 2/5 [s3transfer]
#     Uninstalling awscli-1.18.216:━━━━━━━╺━━━━━━━ 4/5 [awscli]
#       Successfully uninstalled awscli-1.18.216━━━━━━━ 4/5 [awscli]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [awscli]2m4/5 [awscli]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-multimodal 1.4.0 requires nvidia-ml-py3<8.0,>=7.352.0, which is not installed.
# sagemaker-studio 1.1.4 requires pydynamodb>=0.7.4, which is not installed.
# aiobotocore 2.22.0 requires botocore<1.37.4,>=1.37.2, but you have botocore 1.42.29 which is incompatible.
# aiobotocore 2.22.0 requires wrapt<2.0.0,>=1.10.10, but you have wrapt 2.0.1 which is incompatible.
# amazon-sagemaker-sql-execution 0.1.9 requires pyathena<4,>=3.3.0, but you have pyathena 2.1.0 which is incompatible.
# autogluon-multimodal 1.4.0 requires transformers[sentencepiece]<4.50,>=4.38.0, but you have transformers 4.57.3 which is incompatible.
# autogluon-timeseries 1.4.0 requires transformers[sentencepiece]<4.50,>=4.38.0, but you have transformers 4.57.3 which is incompatible.
# sagemaker-core 1.0.67 requires PyYAML<7.0,>=6.0, but you have pyyaml 5.3.1 which is incompatible.
# sagemaker-studio 1.1.4 requires pyathena>=3.18.0, but you have pyathena 2.1.0 which is incompatible.
# sagemaker-studio-analytics-extension 0.2.2 requires sparkmagic==0.22.0, but you have sparkmagic 0.21.0 which is incompatible.
# Successfully installed awscli-1.44.19 boto3-1.42.29 botocore-1.42.29 docutils-0.19 s3transfer-0.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Cell 1: confirm what versions you currently have (optional but useful)
# !python -c "import boto3, botocore, s3transfer; print('boto3', boto3.__version__); print('botocore', botocore.__version__); print('s3transfer', s3transfer.__version__)"
# Out:
# boto3 1.42.29
# botocore 1.42.29
# s3transfer 0.16.0

# %%
# Cell 2: upgrade to a consistent, Studio-compatible AWS SDK set
# !pip install --disable-pip-version-check -q --upgrade "boto3<2" "botocore<2" "s3transfer<2"

# %%
# !pip install -q "protobuf==3.20.*"
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# databricks-sdk 0.74.0 requires protobuf!=5.26.*,!=5.27.*,!=5.28.*,!=5.29.0,!=5.29.1,!=5.29.2,!=5.29.3,!=5.29.4,!=6.30.0,!=6.30.1,!=6.31.0,<7.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.67.1 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.

# %%
import boto3
import sagemaker

session = boto3.session.Session()
region = session.region_name
sagemaker_session = sagemaker.Session()
bucket = sagemaker_session.default_bucket()

s3 = boto3.Session().client(service_name="s3", region_name=region)

# %%
setup_s3_bucket_passed = False

# %%
print("Default bucket: {}".format(bucket))
# Out:
# Default bucket: sagemaker-us-east-1-092122669768

# %% [markdown]
# # Verify S3_BUCKET Bucket Creation

# %%
from botocore.client import ClientError

response = None

try:
    response = s3.head_bucket(Bucket=bucket)
    print(response)
    setup_s3_bucket_passed = True
except ClientError as e:
    print("[ERROR] Cannot find bucket {} in {} due to {}.".format(bucket, response, e))
# Out:
# {'ResponseMetadata': {'RequestId': '72S5J07VHSYEJ0DC', 'HostId': 'uT8sQzWUBzNJb15s9+gh9eQ4skVtp5ZfoVXgOlj0LY6jCowmraE3dlSN8UaeAL7tztiPzHmxRfI=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'uT8sQzWUBzNJb15s9+gh9eQ4skVtp5ZfoVXgOlj0LY6jCowmraE3dlSN8UaeAL7tztiPzHmxRfI=', 'x-amz-request-id': '72S5J07VHSYEJ0DC', 'date': 'Fri, 16 Jan 2026 06:43:28 GMT', 'x-amz-bucket-region': 'us-east-1', 'x-amz-access-point-alias': 'false', 'x-amz-bucket-arn': 'arn:aws:s3:::sagemaker-us-east-1-092122669768', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'BucketArn': 'arn:aws:s3:::sagemaker-us-east-1-092122669768', 'BucketRegion': 'us-east-1', 'AccessPointAlias': False}

# %%
# %store setup_s3_bucket_passed
# Out:
# Stored 'setup_s3_bucket_passed' (bool)

# %%
# %store
# Out:
# Stored variables and their in-db values:
# s3_private_path_tsv                   -> 's3://sagemaker-us-east-1-092122669768/amazon-revi
# s3_public_path_tsv                    -> 's3://aai-540/amazon-reviews-pds/tsv'
# setup_dependencies_passed             -> True
# setup_s3_bucket_passed                -> True

# %% [markdown]
# # Release Resources

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
# Out:
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>

# %%
# %%javascript
#
# try {
#     Jupyter.notebook.save_checkpoint();
#     Jupyter.notebook.session.delete();
# }
# catch(err) {
#     // NoOp
# }
